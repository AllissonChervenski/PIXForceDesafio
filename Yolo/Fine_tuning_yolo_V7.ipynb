# %%
import os
import glob as glob
import matplotlib.pyplot as plt
import random
import cv2

# %%
# Download the dataset.
#!wget https://learnopencv.s3.us-west-2.amazonaws.com/pothole_dataset.zip

# %%
# Extract the dataset.
#!unzip -q pothole_dataset.zip

# %%
# Function to convert bounding boxes in YOLO format to xmin, ymin, xmax, ymax.
def yolo2bbox(bboxes):
    xmin, ymin = bboxes[0]-bboxes[2]/2, bboxes[1]-bboxes[3]/2
    xmax, ymax = bboxes[0]+bboxes[2]/2, bboxes[1]+bboxes[3]/2
    return xmin, ymin, xmax, ymax

# %%
def plot_box(image, bboxes, labels):
    # Need the image height and width to denormalize
    # the bounding box coordinates
    h, w, _ = image.shape
    for box_num, box in enumerate(bboxes):
        x1, y1, x2, y2 = yolo2bbox(box)
        # Denormalize the coordinates.
        xmin = int(x1*w)
        ymin = int(y1*h)
        xmax = int(x2*w)
        ymax = int(y2*h)

        thickness = max(2, int(w/275))
                
        cv2.rectangle(
            image, 
            (xmin, ymin), (xmax, ymax),
            color=(0, 0, 255),
            thickness=thickness
        )
    return image

# %%
# Function to plot images with the bounding boxes.
def plot(image_paths, label_paths, num_samples):
    all_images = []
    all_images.extend(glob.glob(image_paths+'/*.jpg'))
    all_images.extend(glob.glob(image_paths+'/*.JPG'))
    all_labels = glob.glob(label_paths)
    
    all_images.sort()
    all_labels.sort()

    num_images = len(all_images)
    
    plt.figure(figsize=(15, 12))
    for i in range(num_samples):
        j = random.randint(0,num_images-1)
        image = cv2.imread(all_images[j])
        with open(all_labels[j], 'r') as f:
            bboxes = []
            labels = []
            label_lines = f.readlines()
            for label_line in label_lines:
                label = label_line[0]
                bbox_string = label_line[2:]
                x_c, y_c, w, h = bbox_string.split(' ')
                x_c = float(x_c)
                y_c = float(y_c)
                w = float(w)
                h = float(h)
                bboxes.append([x_c, y_c, w, h])
                labels.append(label)
        result_image = plot_box(image, bboxes, labels)
        plt.subplot(2, 2, i+1)
        plt.imshow(result_image[:, :, ::-1])
        plt.axis('off')
    plt.subplots_adjust(wspace=1)
    plt.tight_layout()
    plt.show()

# %%
# Visualize a few training images.
plot(
    image_paths='pothole_dataset/images/train/', 
    label_paths='pothole_dataset/labels/train/*.txt',
    num_samples=4,
)

# %%
if not os.path.exists('yolov7'):
    # !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1094, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1094 (delta 0), reused 1 (delta 0), pack-reused 1091
# Receiving objects: 100% (1094/1094), 69.85 MiB | 6.04 MiB/s, done.
# Resolving deltas: 100% (521/521), done.

# %%
# %cd yolov7
# Out:
# /home/halik/MEGAsync/Detecção_objetos/yolov7

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib>=3.2.2 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (1.23.3)
# Requirement already satisfied: opencv-python>=4.1.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (4.6.0.66)
# Requirement already satisfied: Pillow>=7.1.2 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (9.2.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (6.0)
# Requirement already satisfied: requests>=2.23.0 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.9.1)
# Collecting torch!=1.12.0,>=1.7.0
#   Downloading torch-1.13.0-cp310-cp310-manylinux1_x86_64.whl (890.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.1/890.1 MB ? eta 0:00:000:00:0100:06
# Collecting torchvision!=0.13.0,>=0.8.1
#   Downloading torchvision-0.14.0-cp310-cp310-manylinux1_x86_64.whl (24.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.3/24.3 MB 572.0 kB/s eta 0:00:0000:0100:02
# Collecting tqdm>=4.41.0
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 185.8 kB/s eta 0:00:00a 0:00:01
# Collecting protobuf<4.21.3
#   Downloading protobuf-4.21.2-cp37-abi3-manylinux2014_x86_64.whl (407 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.8/407.8 kB 370.0 kB/s eta 0:00:0000:0100:01
# Collecting tensorboard>=2.4.1
#   Downloading tensorboard-2.11.0-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 947.4 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pandas>=1.1.4 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 21)) (1.5.0)
# Collecting seaborn>=0.11.0
#   Downloading seaborn-0.12.1-py3-none-any.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 kB 1.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipython in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 34)) (8.5.0)
# Requirement already satisfied: psutil in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (5.9.2)
# Collecting thop
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (4.37.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.0.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from matplotlib>=3.2.2->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from requests>=2.23.0->-r requirements.txt (line 9)) (2.1.1)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 455.2 kB/s eta 0:00:0000:0100:14
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 579.5 kB/s eta 0:00:0000:0100:08
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 553.5 kB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 179.3 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (4.3.0)
# Requirement already satisfied: wheel in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (0.37.1)
# Requirement already satisfied: setuptools in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch!=1.12.0,>=1.7.0->-r requirements.txt (line 11)) (65.3.0)
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.51.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 457.9 kB/s eta 0:00:0000:0100:01
# Collecting protobuf<4.21.3
#   Downloading protobuf-3.20.3-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.2 MB/s eta 0:00:0000:0100:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 789.4 kB/s eta 0:00:000:0100:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.15.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.0/177.0 kB 1.6 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting absl-py>=0.4
#   Downloading absl_py-1.3.0-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.6/124.6 kB 957.4 kB/s eta 0:00:0000:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 2.4 MB/s eta 0:00:0000:0100:01m
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from pandas>=1.1.4->-r requirements.txt (line 21)) (2022.2.1)
# Requirement already satisfied: matplotlib-inline in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (4.8.0)
# Requirement already satisfied: stack-data in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (0.5.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (3.0.31)
# Requirement already satisfied: decorator in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (2.13.0)
# Requirement already satisfied: backcall in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (0.2.0)
# Requirement already satisfied: pickleshare in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (0.7.5)
# Requirement already satisfied: traitlets>=5 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from ipython->-r requirements.txt (line 34)) (5.4.0)
# Requirement already satisfied: six>=1.9.0 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->-r requirements.txt (line 17)) (1.16.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 1.4 MB/s eta 0:00:0000:01
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 34)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from pexpect>4.3->ipython->-r requirements.txt (line 34)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->-r requirements.txt (line 34)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->-r requirements.txt (line 17)) (2.1.1)
# Requirement already satisfied: pure-eval in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (0.2.2)
# Requirement already satisfied: executing in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (1.0.0)
# Requirement already satisfied: asttokens in /home/halik/Documents/skin_analysis/lib/python3.10/site-packages (from stack-data->ipython->-r requirements.txt (line 34)) (2.0.8)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 752.5 kB/s eta 0:00:00 0:00:01
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tensorboard-plugin-wit, pyasn1, werkzeug, tqdm, tensorboard-data-server, rsa, pyasn1-modules, protobuf, oauthlib, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, markdown, grpcio, cachetools, absl-py, requests-oauthlib, nvidia-cudnn-cu11, google-auth, torch, seaborn, google-auth-oauthlib, torchvision, thop, tensorboard
# Successfully installed absl-py-1.3.0 cachetools-5.2.0 google-auth-2.15.0 google-auth-oauthlib-0.4.6 grpcio-1.51.1 markdown-3.4.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 oauthlib-3.2.2 protobuf-3.20.3 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 seaborn-0.12.1 tensorboard-2.11.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 thop-0.1.1.post2209072238 torch-1.13.0 torchvision-0.14.0 tqdm-4.64.1 werkzeug-2.2.2

# %%
# %%writefile data/pothole.yaml
# train: ../pothole_dataset/images/train
# val: ../pothole_dataset/images/valid
# test: ../pothole_dataset/images/test
#
# # Classes
# nc: 1  # number of classes
# names: ['pothole']  # class names

# %%
# Download the Tiny model weights.
# !wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-tiny.pt

# %%
# %%writefile cfg/training/yolov7_pothole-tiny.yaml
# # parameters
# nc: 1  # number of classes
# depth_multiple: 1.0  # model depth multiple
# width_multiple: 1.0  # layer channel multiple
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # yolov7-tiny backbone
# backbone:
#   # [from, number, module, args] c2, k=1, s=1, p=None, g=1, act=True
#   [[-1, 1, Conv, [32, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 0-P1/2
#
#    [-1, 1, Conv, [64, 3, 2, None, 1, nn.LeakyReLU(0.1)]],  # 1-P2/4
#
#    [-1, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 7
#
#    [-1, 1, MP, []],  # 8-P3/8
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 14
#
#    [-1, 1, MP, []],  # 15-P4/16
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 21
#
#    [-1, 1, MP, []],  # 22-P5/32
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [256, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [256, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [512, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 28
#   ]
#
# # yolov7-tiny head
# head:
#   [[-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, SP, [5]],
#    [-2, 1, SP, [9]],
#    [-3, 1, SP, [13]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -7], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 37
#
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [21, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]], # route backbone P4
#    [[-1, -2], 1, Concat, [1]],
#
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 47
#
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [14, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]], # route backbone P3
#    [[-1, -2], 1, Concat, [1]],
#
#    [-1, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [32, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [32, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 57
#
#    [-1, 1, Conv, [128, 3, 2, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, 47], 1, Concat, [1]],
#
#    [-1, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [64, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [64, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 65
#
#    [-1, 1, Conv, [256, 3, 2, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, 37], 1, Concat, [1]],
#
#    [-1, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-2, 1, Conv, [128, 1, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [-1, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [[-1, -2, -3, -4], 1, Concat, [1]],
#    [-1, 1, Conv, [256, 1, 1, None, 1, nn.LeakyReLU(0.1)]],  # 73
#
#    [57, 1, Conv, [128, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [65, 1, Conv, [256, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#    [73, 1, Conv, [512, 3, 1, None, 1, nn.LeakyReLU(0.1)]],
#
#    [[74,75,76], 1, IDetect, [nc, anchors]],   # Detect(P3, P4, P5)
#   ]

# %%
# !python train.py --epochs 100 --workers 4 --device 0 --batch-size 32 \
--data data/pothole.yaml --img 640 640 --cfg cfg/training/yolov7_pothole-tiny.yaml \
--weights 'yolov7-tiny.pt' --name yolov7_tiny_pothole_fixed_res --hyp data/hyp.scratch.tiny.yaml
